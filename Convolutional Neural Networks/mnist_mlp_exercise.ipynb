# %% [markdown]
# # Multi-Layer Perceptron, MNIST
# ---
# In this notebook, we will train an MLP to classify images from the [MNIST database](http://yann.lecun.com/exdb/mnist/) hand-written digit database.
#
# The process will be broken down into the following steps:
# >1. Load and visualize the data
# 2. Define a neural network
# 3. Train the model
# 4. Evaluate the performance of our trained model on a test dataset!
#
# Before we begin, we have to import the necessary libraries for working with data and PyTorch.

# %%
# import libraries
import torch
import numpy as np

# %% [markdown]
# ---
# ## Load and Visualize the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)
#
# Downloading may take a few moments, and you should see your progress as the data is loading. You may also choose to change the `batch_size` if you want to load more data at a time.
#
# This cell will create DataLoaders for each of our datasets.

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20

valid_size=0.2

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# choose the training and test datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

num_train=len(train_data)
indices=list(range(num_train))
np.random.shuffle(indices)
split=int(np.floor(valid_size*num_train))
train_idx,valid_idx=indices[split:],indices[split:]

train_sampler=SubsetRandomSampler(train_idx)
valid_sampler=SubsetRandomSampler(valid_idx)


# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,sampler=train_sampler,
    num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,sampler=valid_sampler,
    num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# %% [markdown]
# ### Visualize a Batch of Training Data
#
# The first step in a classification task is to take a look at the data, make sure it is loaded in correctly, then make any initial observations about patterns in that data.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    # print out the correct label for each image
    # .item() gets the value contained in a Tensor
    ax.set_title(str(labels[idx].item()))

# %% [markdown]
# ### View an Image in More Detail

# %%
img = np.squeeze(images[1])

fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Define the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
# The architecture will be responsible for seeing as input a 784-dim Tensor of pixel values for each image, and producing a Tensor of length 10 (our number of classes) that indicates the class scores for an input image. This particular example uses two hidden layers and dropout to avoid overfitting.

# %%
import torch.nn as nn
import torch.nn.functional as F

## TODO: Define the NN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # linear layer (784 -> 1 hidden node)
        self.fc1 = nn.Linear(28 * 28, 512)
        self.fc2 = nn.Linear(512, 512)
        self.output = nn.Linear(512, 10)
        self.dropout=nn.Dropout(0.2)
        

    def forward(self, x):
        # flatten image input
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        x=self.dropout(x)
        x = F.relu(self.fc2(x))
        x=self.dropout(x)
        x = F.relu(self.output(x))
        return x

# initialize the NN
model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (output): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %% [markdown]
# ###  Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# It's recommended that you use cross-entropy loss for classification. If you look at the documentation (linked above), you can see that PyTorch's cross entropy function applies a softmax funtion to the output layer *and* then calculates the log loss.

# %%
## TODO: Specify loss and optimization functions

# specify loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = torch.optim.SGD(model.parameters(),lr=0.01)

# %% [markdown]
# ---
# ## Train the Network
#
# The steps for training/learning from a batch of data are described in the comments below:
# 1. Clear the gradients of all optimized variables
# 2. Forward pass: compute predicted outputs by passing inputs to the model
# 3. Calculate the loss
# 4. Backward pass: compute gradient of the loss with respect to model parameters
# 5. Perform a single optimization step (parameter update)
# 6. Update average training loss
#
# The following loop trains for 30 epochs; feel free to change this number. For now, we suggest somewhere between 20-50 epochs. As you train, take a look at how the values for the training loss decrease over time. We want it to decrease while also avoiding overfitting the training data.

# %%
# number of epochs to train the model
n_epochs = 50  # suggest training between 20-50 epochs

valid_loss_min=np.Inf

model.train() # prep model for training

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss=0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    for data,target in valid_loader:
        output=model(data)
        loss=criterion(output,target)
        valid_loss+=loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)

    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation loss {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    if valid_loss<=valid_loss_min:
        print('Validation loss decreased ({:.6f} ----> {:.6f}.  Saving model....'.format(
        valid_loss_min,
            valid_loss,
        ))
        torch.save(model.state_dict(),'model.pt')
        valid_loss_min=valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.289267 	Validation loss 0.244110
# Validation loss decreased (inf ----> 0.244110.  Saving model....
# Epoch: 2 	Training Loss: 0.225271 	Validation loss 0.198935
# Validation loss decreased (0.244110 ----> 0.198935.  Saving model....
# Epoch: 3 	Training Loss: 0.185368 	Validation loss 0.166395
# Validation loss decreased (0.198935 ----> 0.166395.  Saving model....
# Epoch: 4 	Training Loss: 0.156144 	Validation loss 0.141126
# Validation loss decreased (0.166395 ----> 0.141126.  Saving model....
# Epoch: 5 	Training Loss: 0.135005 	Validation loss 0.123859
# Validation loss decreased (0.141126 ----> 0.123859.  Saving model....
# Epoch: 6 	Training Loss: 0.120067 	Validation loss 0.109616
# Validation loss decreased (0.123859 ----> 0.109616.  Saving model....
# Epoch: 7 	Training Loss: 0.107262 	Validation loss 0.099229
# Validation loss decreased (0.109616 ----> 0.099229.  Saving model....
# Epoch: 8 	Training Loss: 0.097273 	Validation loss 0.089091
# Validation loss decreased (0.099229 ----> 0.089091.  Saving model....
# Epoch: 9 	Training Loss: 0.088164 	Validation loss 0.080727
# Validation loss decreased (0.089091 ----> 0.080727.  Saving model....
# Epoch: 10 	Training Loss: 0.081284 	Validation loss 0.075438
# Validation loss decreased (0.080727 ----> 0.075438.  Saving model....
# Epoch: 11 	Training Loss: 0.075062 	Validation loss 0.068571
# Validation loss decreased (0.075438 ----> 0.068571.  Saving model....
# Epoch: 12 	Training Loss: 0.069513 	Validation loss 0.063089
# Validation loss decreased (0.068571 ----> 0.063089.  Saving model....
# Epoch: 13 	Training Loss: 0.064113 	Validation loss 0.059896
# Validation loss decreased (0.063089 ----> 0.059896.  Saving model....
# Epoch: 14 	Training Loss: 0.060688 	Validation loss 0.055709
# Validation loss decreased (0.059896 ----> 0.055709.  Saving model....
# Epoch: 15 	Training Loss: 0.056109 	Validation loss 0.052774
# Validation loss decreased (0.055709 ----> 0.052774.  Saving model....
# Epoch: 16 	Training Loss: 0.053086 	Validation loss 0.047716
# Validation loss decreased (0.052774 ----> 0.047716.  Saving model....
# Epoch: 17 	Training Loss: 0.049542 	Validation loss 0.047324
# Validation loss decreased (0.047716 ----> 0.047324.  Saving model....
# Epoch: 18 	Training Loss: 0.045852 	Validation loss 0.042802
# Validation loss decreased (0.047324 ----> 0.042802.  Saving model....
# Epoch: 19 	Training Loss: 0.044413 	Validation loss 0.039712
# Validation loss decreased (0.042802 ----> 0.039712.  Saving model....
# Epoch: 20 	Training Loss: 0.041429 	Validation loss 0.037469
# Validation loss decreased (0.039712 ----> 0.037469.  Saving model....
# Epoch: 21 	Training Loss: 0.038409 	Validation loss 0.035298
# Validation loss decreased (0.037469 ----> 0.035298.  Saving model....
# Epoch: 22 	Training Loss: 0.036847 	Validation loss 0.035969
# Epoch: 23 	Training Loss: 0.035136 	Validation loss 0.032143
# Validation loss decreased (0.035298 ----> 0.032143.  Saving model....
# Epoch: 24 	Training Loss: 0.033590 	Validation loss 0.029823
# Validation loss decreased (0.032143 ----> 0.029823.  Saving model....
# Epoch: 25 	Training Loss: 0.031566 	Validation loss 0.029655
# Validation loss decreased (0.029823 ----> 0.029655.  Saving model....
# Epoch: 26 	Training Loss: 0.028955 	Validation loss 0.028731
# Validation loss decreased (0.029655 ----> 0.028731.  Saving model....
# Epoch: 27 	Training Loss: 0.028986 	Validation loss 0.026078
# Validation loss decreased (0.028731 ----> 0.026078.  Saving model....
# Epoch: 28 	Training Loss: 0.026330 	Validation loss 0.025138
# Validation loss decreased (0.026078 ----> 0.025138.  Saving model....
# Epoch: 29 	Training Loss: 0.026174 	Validation loss 0.023624
# Validation loss decreased (0.025138 ----> 0.023624.  Saving model....
# Epoch: 30 	Training Loss: 0.024292 	Validation loss 0.022006
# Validation loss decreased (0.023624 ----> 0.022006.  Saving model....
# Epoch: 31 	Training Loss: 0.023180 	Validation loss 0.021332
# Validation loss decreased (0.022006 ----> 0.021332.  Saving model....
# Epoch: 32 	Training Loss: 0.022894 	Validation loss 0.020063
# Validation loss decreased (0.021332 ----> 0.020063.  Saving model....
# Epoch: 33 	Training Loss: 0.020487 	Validation loss 0.019891
# Validation loss decreased (0.020063 ----> 0.019891.  Saving model....
# Epoch: 34 	Training Loss: 0.020435 	Validation loss 0.018882
# Validation loss decreased (0.019891 ----> 0.018882.  Saving model....
# Epoch: 35 	Training Loss: 0.019671 	Validation loss 0.017371
# Validation loss decreased (0.018882 ----> 0.017371.  Saving model....
# Epoch: 36 	Training Loss: 0.019402 	Validation loss 0.016884
# Validation loss decreased (0.017371 ----> 0.016884.  Saving model....
# Epoch: 37 	Training Loss: 0.018349 	Validation loss 0.016414
# Validation loss decreased (0.016884 ----> 0.016414.  Saving model....
# Epoch: 38 	Training Loss: 0.016884 	Validation loss 0.015468
# Validation loss decreased (0.016414 ----> 0.015468.  Saving model....
# Epoch: 39 	Training Loss: 0.015688 	Validation loss 0.014468
# Validation loss decreased (0.015468 ----> 0.014468.  Saving model....
# Epoch: 40 	Training Loss: 0.015359 	Validation loss 0.015142
# Epoch: 41 	Training Loss: 0.014672 	Validation loss 0.014077
# Validation loss decreased (0.014468 ----> 0.014077.  Saving model....
# Epoch: 42 	Training Loss: 0.014157 	Validation loss 0.013048
# Validation loss decreased (0.014077 ----> 0.013048.  Saving model....
# Epoch: 43 	Training Loss: 0.013847 	Validation loss 0.012580
# Validation loss decreased (0.013048 ----> 0.012580.  Saving model....
# Epoch: 44 	Training Loss: 0.013591 	Validation loss 0.011876
# Validation loss decreased (0.012580 ----> 0.011876.  Saving model....
# Epoch: 45 	Training Loss: 0.012889 	Validation loss 0.011278
# Validation loss decreased (0.011876 ----> 0.011278.  Saving model....
# Epoch: 46 	Training Loss: 0.012030 	Validation loss 0.010841
# Validation loss decreased (0.011278 ----> 0.010841.  Saving model....
# Epoch: 47 	Training Loss: 0.012167 	Validation loss 0.012009
# Epoch: 48 	Training Loss: 0.011609 	Validation loss 0.010952
# Epoch: 49 	Training Loss: 0.011356 	Validation loss 0.010515
# Validation loss decreased (0.010841 ----> 0.010515.  Saving model....
# Epoch: 50 	Training Loss: 0.010136 	Validation loss 0.009816
# Validation loss decreased (0.010515 ----> 0.009816.  Saving model....

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Finally, we test our best model on previously unseen **test data** and evaluate it's performance. Testing on unseen data is a good way to check that our model generalizes well. It may also be useful to be granular in this analysis and take a look at how this model performs on each class as well as looking at its overall loss and accuracy.
#
# #### `model.eval()`
#
# `model.eval(`) will set all the layers in your model to evaluation mode. This affects layers like dropout layers that turn "off" nodes during training with some probability, but should allow every node to be "on" for evaluation!

# %%
model.load_state_dict(torch.load('model.pt'))

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() # prep model for *evaluation*

for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print avg test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.057603
#
# Test Accuracy of     0: 99% (972/980)
# Test Accuracy of     1: 99% (1127/1135)
# Test Accuracy of     2: 97% (1011/1032)
# Test Accuracy of     3: 98% (998/1010)
# Test Accuracy of     4: 98% (963/982)
# Test Accuracy of     5: 97% (874/892)
# Test Accuracy of     6: 98% (940/958)
# Test Accuracy of     7: 97% (1005/1028)
# Test Accuracy of     8: 97% (947/974)
# Test Accuracy of     9: 97% (979/1009)
#
# Test Accuracy (Overall): 98% (9816/10000)

# %% [markdown]
# ### Visualize Sample Test Results
#
# This cell displays test images and their labels in this format: `predicted (ground-truth)`. The text will be green for accurately classified examples and red for incorrect predictions.

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))
